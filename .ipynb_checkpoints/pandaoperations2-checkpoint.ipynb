# %%
pandas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-609b6d5922fb> in <module>
# ----> 1 pandas
#
# NameError: name 'pandas' is not defined

# %%
pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2337d7da5ae8> in <module>
# ----> 1 pd
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
from royaltyapp.income.helpers import StatementFactory, find_distinct_version_matching_errors, find_distinct_track_matching_errors, find_distinct_refund_matching_errors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-dda8d62022c1> in <module>
# ----> 1 from royaltyapp.income.helpers import StatementFactory, find_distinct_version_matching_errors, find_distinct_track_matching_errors, find_distinct_refund_matching_errors
#
# ~/Documents/programming/projects/royaltyappv4/royaltyapp/__init__.py in <module>
# ----> 1 from flask import Flask
#       2 from flask_sqlalchemy import SQLAlchemy
#       3 from flask_cors import CORS
#       4 from royaltyapp.models import db, ma
#       5 from royaltyapp.cache import cache
#
# ModuleNotFoundError: No module named 'flask'

# %%
from flask import Flask
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-6769915e1957> in <module>
# ----> 1 from flask import Flask
#
# ModuleNotFoundError: No module named 'flask'

# %%
import os

# %%
path = os.getcwd() + '/bandcamp.csv'

# %%
encoding_options = 'utf_16'
dtype_options = { 'catalog number': 'str', 'sku': 'str', 'upc': 'str' }

# %%
import numpy as np

# %%
df = pd.read_csv(path, encoding=encoding_options, dtype=dtype_options)
pd.set_option('display.max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-26d02e0684b8> in <module>
# ----> 1 df = pd.read_csv(path, encoding=encoding_options, dtype=dtype_options)
#       2 pd.set_option('display.max_columns', None)
#
# NameError: name 'pd' is not defined

# %%
df.loc[df['item type'] == 'reversal'].groupby(['bandcamp transaction id']).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9dbcf22914c4> in <module>
# ----> 1 df.loc[df['item type'] == 'reversal'].groupby(['bandcamp transaction id']).sum()
#
# NameError: name 'df' is not defined

# %%
total_price = df.loc[df['item type'] == 'reversal'].groupby(['bandcamp transaction id']).sum()[['item total']]

# %%
reversal = df.loc[df['item type'] == 'reversal'][['bandcamp transaction id', 'item total']]

# %%
sum = reversal.reset_index().merge(total_price, on='bandcamp transaction id')

# %%
change_to_payout = df.loc[df['item type'] == 'reversal'].groupby(['bandcamp transaction id']).sum()[['change to payout balance']]

# %%
joined = sum.merge(change_to_payout, on='bandcamp transaction id')

# %%
joined['new_net'] = joined['item total_x']/joined['item total_y']*joined['change to payout balance']

# %%
joined = joined.set_index('index')[['new_net']]

# %%
df = df.join(joined, lsuffix='_left', rsuffix='_right' )

# %%
types_to_change = ['refund', 'reversal']

# %%
df.loc[df['item type'].isin(types_to_change), 'net amount'] = df['new_net']

# %%
df.loc[df['item type'] == 'refund']
# Out:
#                  date              paid to item type  \
# 827     3/5/19 6:57pm   ckirkley@gmail.com    refund
# 873     3/8/19 5:16pm             Bandcamp    refund
# 1955   4/19/19 8:34pm             Bandcamp    refund
# 1956   4/19/19 8:49pm             Bandcamp    refund
# 1957   4/19/19 8:49pm             Bandcamp    refund
# 2495   5/30/19 4:08pm  paypal@bandcamp.com    refund
# 2699  6/20/19 10:05pm   ckirkley@gmail.com    refund
# 3271   7/23/19 6:56pm             Bandcamp    refund
# 3395   7/31/19 7:14pm             Bandcamp    refund
# 3579    8/6/19 7:19pm             Bandcamp    refund
# 3867   8/28/19 4:17pm             Bandcamp    refund
#
#                                     item name                    artist  \
# 827                                   Fasokan          Luka Productions
# 873                  Les Filles de Illighadad  Les Filles de Illighadad
# 1955                                Houmeissa                      Hama
# 1956                       Ilana: The Creator               Mdou Moctar
# 1957                 Les Filles de Illighadad  Les Filles de Illighadad
# 2495                       Ilana: The Creator               Mdou Moctar
# 2699                                  Fasokan          Luka Productions
# 3271                                 Terrouzi       Ahmedou Ahmed Lowla
# 3395  Zerzura (Original Soundtrack Recording)        Ahmoudou Madassane
# 3579                             Eghass Malan  Les Filles de Illighadad
# 3867                              Anou Malane   Abdallah Ag Oumbadougou
#
#      currency  item price  quantity discount code  sub total  tax  shipping  \
# 827       USD        10.0      -1.0           NaN      -10.0  NaN      -2.0
# 873       USD        17.0      -1.0           NaN      -17.0  NaN      -5.0
# 1955      USD        17.0       NaN           NaN       -5.0  NaN       NaN
# 1956      USD        17.0      -1.0           NaN      -17.0  NaN      -2.0
# 1957      USD        17.0      -1.0           NaN      -17.0  NaN      -5.0
# 2495      USD        14.0      -1.0           NaN      -14.0  NaN       NaN
# 2699      USD        10.0      -1.0           NaN      -10.0  NaN      -4.0
# 3271      USD        15.0      -1.0           NaN      -15.0  NaN     -10.0
# 3395      USD        15.0       NaN           NaN      -10.0  NaN       NaN
# 3579      USD        15.0      -1.0           NaN      -15.0  NaN      -5.0
# 3867      USD         8.0      -1.0           NaN       -8.0  NaN      -3.0
#
#      ship from country name  transaction fee     fee type  item total  \
# 827                 Germany              NaN          NaN       -12.0
# 873           United States            -0.72       paypal       -22.0
# 1955          United States            -0.16       paypal        -5.0
# 1956          United States            -1.08       paypal       -19.0
# 1957          United States              NaN          NaN       -22.0
# 2495                    NaN            -0.57       paypal       -14.0
# 2699                Germany              NaN          NaN       -14.0
# 3271          United States            -1.03       paypal       -25.0
# 3395          United States            -0.41       paypal       -10.0
# 3579          United States            -0.68       paypal       -20.0
# 3867          United States            -0.54  credit card       -11.0
#
#       amount you received bandcamp transaction id paypal transaction id  \
# 827                   NaN              t184475731     20983458P56566932
# 873                   NaN              t185046430                   NaN
# 1955                  NaN              t193126780                   NaN
# 1956                  NaN              t193129493                   NaN
# 1957                  NaN              t193129493                   NaN
# 2495                  NaN              t200907118     73772578292413454
# 2699                  NaN              t205439926     8N8501137S590815L
# 3271                  NaN              t211700875                   NaN
# 3395                  NaN              t213231368                   NaN
# 3579                  NaN              t214390529                   NaN
# 3867                  NaN              t218638708                   NaN
#
#       assessed revenue share  collected revenue share  \
# 827                      NaN                      NaN
# 873                    -1.70                    -1.70
# 1955                   -0.39                    -0.39
# 1956                   -3.40                    -3.40
# 1957                     NaN                      NaN
# 2495                   -1.40                    -1.40
# 2699                     NaN                      NaN
# 3271                   -1.50                    -1.50
# 3395                   -0.60                    -0.60
# 3579                   -1.50                    -1.50
# 3867                   -0.80                    -0.80
#
#       balance of revenue share  change to payout balance  payout balance  \
# 827                        NaN                       NaN             NaN
# 873                        0.0                    -19.58          185.87
# 1955                       0.0                     -4.45          341.11
# 1956                       0.0                    -36.52          304.59
# 1957                       NaN                       NaN             NaN
# 2495                       0.0                    -12.03           36.67
# 2699                       NaN                       NaN             NaN
# 3271                       0.0                    -22.47          241.24
# 3395                       0.0                     -8.99          155.85
# 3579                       0.0                    -17.82          150.56
# 3867                       0.0                     -9.66          878.28
#
#       net amount                            package option  \
# 827          NaN           Limited Edition Cassette    NaN
# 873          NaN        Les Filles de Illighadad LP    NaN
# 1955         NaN                Hama - Houmeissa LP    NaN
# 1956         NaN  Ilana LP - 2nd Pressing Pre-Order    NaN
# 1957         NaN        Les Filles de Illighadad LP    NaN
# 2495         NaN                   digital download    NaN
# 2699         NaN           Limited Edition Cassette    NaN
# 3271         NaN       Limited Edition Compact Disc    NaN
# 3395         NaN                        Zerzura DVD    NaN
# 3579         NaN          Vinyl LP - WAREHOUSE FIND    NaN
# 3867         NaN           Limited Edition Cassette    NaN
#
#                                                item url             sku  \
# 827   http://lukaproductions.bandcamp.com/album/fasokan        LP-F-LEC
# 873   http://lesfillesdeillighadad.bandcamp.com/albu...  LFDI-LFDI-LFDI
# 1955      http://hamasynth.bandcamp.com/album/houmeissa        SS-049lp
# 1956  http://mdoumoctar.bandcamp.com/album/ilana-the...        SS-051lp
# 1957  http://lesfillesdeillighadad.bandcamp.com/albu...        SS-033lp
# 2495  http://mdoumoctar.bandcamp.com/album/ilana-the...             NaN
# 2699  http://lukaproductions.bandcamp.com/album/fasokan        LP-F-LEC
# 3271  http://ahmedouahmedlowla.bandcamp.com/album/te...       SS-054-CD
# 3395  http://sahelsounds.bandcamp.com/merch/zerzura-dvd       SS-046DVD
# 3579  http://lesfillesdeillighadad.bandcamp.com/albu...        SS-044lp
# 3867  http://abdallahagoumbadougou.bandcamp.com/albu...      SS-053cass
#
#      catalog number            upc  isrc         buyer name  \
# 827          SS-040            NaN   NaN  Michael Unterberg
# 873          SS-033  889326 664918   NaN    lyle r fritchey
# 1955         SS-049  656605 382364   NaN    Dean Tisthammer
# 1956         SS-051  602318 136893   NaN        Brian Burns
# 1957         SS-033  889326 664918   NaN        Brian Burns
# 2495         SS-051  602318 136893   NaN    Kristen Deupree
# 2699         SS-040  889326 900344   NaN      Benjamin Wood
# 3271         SS-054  602318 137029   NaN     francis breton
# 3395            NaN            NaN   NaN        ELias Pahls
# 3579         SS-044  191515 928351   NaN       Erin Coppola
# 3867         SS-053  602318 136992   NaN     Kevin Cosgrove
#
#                    buyer email      buyer phone buyer note       ship to name  \
# 827         bartleby666@gmx.de  +49 04043276788        NaN  Michael Unterberg
# 873         uberlyle@yahoo.com     916-288-7299        NaN      Lyle Fritchey
# 1955  d.tisthammer13@gmail.com     707-484-4418        NaN    Dean Tisthammer
# 1956       BBurns119@yahoo.com     919-260-1677        NaN        Brian Burns
# 1957       BBurns119@yahoo.com     919-260-1677        NaN        Brian Burns
# 2495       kadeupree@gmail.com              NaN   marry me                NaN
# 2699  benjaminjswood@gmail.com     647-458-7001        NaN      Benjamin Wood
# 3271  breton_francis@orange.fr    +33 169839477        NaN     Francis Breton
# 3395     elias.pahls@gmail.com   +41 0786931513        NaN        Elias Pahls
# 3579    coppola.erin@gmail.com     702-480-7161        NaN       Erin Coppola
# 3867          kcsgrv@gmail.com              NaN        NaN     Kevin Cosgrove
#
#                           ship to street ship to street 2 ship to city  \
# 827                  Warnstedtstraße 59a              NaN      Hamburg
# 873                      2015 Larkin Way              NaN   Sacramento
# 1955                   237 Cleveland Ave              NaN     Petaluma
# 1956              102 Spring Valley Road              NaN     Carrboro
# 1957              102 Spring Valley Road              NaN     Carrboro
# 2495                                 NaN              NaN          NaN
# 2699  1586 Queen St West, Apartment #202              NaN      Toronto
# 3271           13 rue Pierre Brossolette              NaN       Yerres
# 3395                 Effretikonerstrasse              NaN       Illnau
# 3579               10905 NE Tillamook St              NaN     Portland
# 3867                     3735 S Wood St.           Unit 2      Chicago
#
#      ship to state ship to zip ship to country ship to country code ship date  \
# 827            NaN       22525         Germany                   DE       NaN
# 873             CA  95818-2420   United States                   US       NaN
# 1955            CA       94952   United States                   US       NaN
# 1956            NC       27510   United States                   US       NaN
# 1957            NC       27510   United States                   US       NaN
# 2495           NaN         NaN             NaN                  NaN       NaN
# 2699            ON     M6R 1A8          Canada                   CA       NaN
# 3271           NaN       91330          France                   FR       NaN
# 3395        Zürich        8308     Switzerland                   CH       NaN
# 3579            OR       97220   United States                   US       NaN
# 3867            IL       60609   United States                   US       NaN
#
#      ship notes        country country code region/state        city  \
# 827         NaN        Germany           DE          NaN     Hamburg
# 873         NaN  United States           US           CA  Sacramento
# 1955        NaN  United States           US           CA    Petaluma
# 1956        NaN  United States           US           NC    Carrboro
# 1957        NaN  United States           US           NC    Carrboro
# 2495        NaN  United States           US           TX   Palestine
# 2699        NaN         Canada           CA           ON     Toronto
# 3271        NaN         France           FR          NaN      Yerres
# 3395        NaN    Switzerland           CH       Zürich      Illnau
# 3579        NaN  United States           US           OR    Portland
# 3867        NaN  United States           US           IL     Chicago
#
#                                         referrer  \
# 827                                          NaN
# 873   Recommendations footer: commonly collected
# 1955                             sahelsounds.com
# 1956      Bandcamp artist: lesfillesdeillighadad
# 1957                                         NaN
# 2495                       Bandcamp fan wishlist
# 2699                               Google search
# 3271                                         NaN
# 3395                               Google search
# 3579                             Bandcamp search
# 3867                                         NaN
#
#                                            referrer url  new_net_left  \
# 827                                                 NaN           NaN
# 873                   bandcamp.com/footer/cc/a141892888           NaN
# 1955            sahelsounds.com/2019/01/hama-houmeissa/           NaN
# 1956  lesfillesdeillighadad.bandcamp.com/album/les-f...           NaN
# 1957                                                NaN           NaN
# 2495                  bandcamp.com/app/android/wishlist           NaN
# 2699                                    www.google.com/           NaN
# 3271                                                NaN           NaN
# 3395                                    www.google.com/           NaN
# 3579                   bandcamp.com/autocomplete-search           NaN
# 3867                                                NaN           NaN
#
#       new_net_right  new_net
# 827             NaN      NaN
# 873             NaN      NaN
# 1955            NaN      NaN
# 1956            NaN      NaN
# 1957            NaN      NaN
# 2495            NaN      NaN
# 2699            NaN      NaN
# 3271            NaN      NaN
# 3395            NaN      NaN
# 3579            NaN      NaN
# 3867            NaN      NaN
